# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series / Seriler

# %%
benimSozlugum = {"Kadir" : 50, "Ali" : 40, "Mehmet" : 30}

# %%
pd.Series(benimSozlugum)
# Out:
# Kadir     50
# Ali       40
# Mehmet    30
# dtype: int64

# %%
benimYaslarim = [50,40,30]
benimIsimlerim = ["Kadir","Ali","Mehmet"]

# %%
pd.Series(benimYaslarim)
# Out:
# 0    50
# 1    40
# 2    30
# dtype: int64

# %%
pd.Series(benimYaslarim,benimIsimlerim)
# Out:
# Kadir     50
# Ali       40
# Mehmet    30
# dtype: int64

# %%
pd.Series(data = benimYaslarim, index = benimIsimlerim)
# Out:
# Kadir     50
# Ali       40
# Mehmet    30
# dtype: int64

# %%
numpyDizisi = np.array([50,40,30])

# %%
numpyDizisi
# Out:
# array([50, 40, 30])

# %%
pd.Series(numpyDizisi, benimIsimlerim)
# Out:
# Kadir     50
# Ali       40
# Mehmet    30
# dtype: int64

# %%
## Seriler ile farklı veri tipleri tutulabilir.

# %%
pd.Series(["Kadir","Atlas","Osman"],[1,2,3])
# Out:
# 1    Kadir
# 2    Atlas
# 3    Osman
# dtype: object

# %%
yarismaSonucu1 = pd.Series([10,5,1],["Kadir","Atlas","Osman"])

# %%
yarismaSonucu1
# Out:
# Kadir    10
# Atlas     5
# Osman     1
# dtype: int64

# %%
yarismaSonucu2 = pd.Series([20,10,8],["Kadir","Atlas","Osman"])

# %%
yarismaSonucu2
# Out:
# Kadir    20
# Atlas    10
# Osman     8
# dtype: int64

# %%
print(yarismaSonucu2["Atlas"])
# Out:
# 10

# %%
sonSonuc = yarismaSonucu1 + yarismaSonucu2

# %%
sonSonuc
# Out:
# Kadir    30
# Atlas    15
# Osman     9
# dtype: int64

# %%
farkliSeries = pd.Series([20,30,40,50],["a","b","c","d"])

# %%
farkliSeries2 = pd.Series([10,5,3,1],["a","c","f","g"])

# %%
farkliSeries
# Out:
# a    20
# b    30
# c    40
# d    50
# dtype: int64

# %%
farkliSeries2
# Out:
# a    10
# c     5
# f     3
# g     1
# dtype: int64

# %%
farkliSeries + farkliSeries2
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
