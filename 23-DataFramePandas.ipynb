# %%
import pandas as pd
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-1.14938528e+00,  1.11758015e+00,  2.73085011e+00],
#        [-1.91040173e-01, -1.72570283e-04,  1.07910168e+00],
#        [ 7.43445747e-01, -9.51107243e-01,  2.55509955e-01],
#        [-8.12931368e-01,  1.67615800e+00,  1.00672292e+00]])

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame
# Out:
#           0         1         2
# 0  0.548051  1.295176 -0.761422
# 1  1.763184  0.209048  0.522082
# 2  0.968224 -0.000417  1.127900
# 3  0.060668 -1.168144  0.500326

# %%
dataFrame[0]
# Out:
# 0    0.548051
# 1    1.763184
# 2    0.968224
# 3    0.060668
# Name: 0, dtype: float64

# %%
type(dataFrame[0])
# Out:
# pandas.core.series.Series

# %%
yeniDataFrame = pd.DataFrame(data, index = ["Kadir","Atlas","Mehmet","Tugce"], columns = ["Maas","Yas","Calisma Saati"])

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniDataFrame["Yas"]
# Out:
# Kadir     1.295176
# Atlas     0.209048
# Mehmet   -0.000417
# Tugce    -1.168144
# Name: Yas, dtype: float64

# %%
yeniDataFrame["Calisma Saati"]
# Out:
# Kadir    -0.761422
# Atlas     0.522082
# Mehmet    1.127900
# Tugce     0.500326
# Name: Calisma Saati, dtype: float64

# %%
yeniDataFrame[["Maas","Yas"]]
# Out:
#             Maas       Yas
# Kadir   0.548051  1.295176
# Atlas   1.763184  0.209048
# Mehmet  0.968224 -0.000417
# Tugce   0.060668 -1.168144

# %%
yeniDataFrame.loc["Kadir"]
# Out:
# Maas             0.548051
# Yas              1.295176
# Calisma Saati   -0.761422
# Name: Kadir, dtype: float64

# %%
yeniDataFrame.loc["Tugce"]
# Out:
# Maas             0.060668
# Yas             -1.168144
# Calisma Saati    0.500326
# Name: Tugce, dtype: float64

# %%
yeniDataFrame.iloc[3]
# Out:
# Maas             0.060668
# Yas             -1.168144
# Calisma Saati    0.500326
# Name: Tugce, dtype: float64

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniDataFrame["Emeklilik Yasi"] = yeniDataFrame["Yas"] + yeniDataFrame["Yas"]

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati  Emeklilik Yasi
# Kadir   0.548051  1.295176      -0.761422        2.590351
# Atlas   1.763184  0.209048       0.522082        0.418096
# Mehmet  0.968224 -0.000417       1.127900       -0.000833
# Tugce   0.060668 -1.168144       0.500326       -2.336288

# %%
yeniDataFrame.drop("Emeklilik Yasi", axis = 1)
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniDataFrame.drop(["Mehmet"] , axis = 0)
# Out:
#            Maas       Yas  Calisma Saati  Emeklilik Yasi
# Kadir  0.548051  1.295176      -0.761422        2.590351
# Atlas  1.763184  0.209048       0.522082        0.418096
# Tugce  0.060668 -1.168144       0.500326       -2.336288

# %%
yeniDataFrame.drop(["Emeklilik Yasi"], axis = 1, inplace = True)

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniDataFrame.loc["Kadir"]["Yas"]
# Out:
# np.float64(1.2951755155325553)

# %%
yeniDataFrame.loc["Atlas"]["Yas"]
# Out:
# np.float64(0.2090478483167673)

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniDataFrame < 0
# Out:
#          Maas    Yas  Calisma Saati
# Kadir   False  False           True
# Atlas   False  False          False
# Mehmet  False   True          False
# Tugce   False   True          False

# %%
booleanFrame = yeniDataFrame < 0

# %%
booleanFrame
# Out:
#          Maas    Yas  Calisma Saati
# Kadir   False  False           True
# Atlas   False  False          False
# Mehmet  False   True          False
# Tugce   False   True          False

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniDataFrame[booleanFrame]
# Out:
#         Maas       Yas  Calisma Saati
# Kadir    NaN       NaN      -0.761422
# Atlas    NaN       NaN            NaN
# Mehmet   NaN -0.000417            NaN
# Tugce    NaN -1.168144            NaN

# %%
yeniDataFrame[yeniDataFrame < 0]
# Out:
#         Maas       Yas  Calisma Saati
# Kadir    NaN       NaN      -0.761422
# Atlas    NaN       NaN            NaN
# Mehmet   NaN -0.000417            NaN
# Tugce    NaN -1.168144            NaN

# %%
yeniDataFrame[yeniDataFrame > 0]
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176            NaN
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224       NaN       1.127900
# Tugce   0.060668       NaN       0.500326

# %%
yeniDataFrame[yeniDataFrame > 0]
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176            NaN
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224       NaN       1.127900
# Tugce   0.060668       NaN       0.500326

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniDataFrame[yeniDataFrame["Yas"] > 0]
# Out:
#            Maas       Yas  Calisma Saati
# Kadir  0.548051  1.295176      -0.761422
# Atlas  1.763184  0.209048       0.522082

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniDataFrame.reset_index()
# Out:
#     index      Maas       Yas  Calisma Saati
# 0   Kadir  0.548051  1.295176      -0.761422
# 1   Atlas  1.763184  0.209048       0.522082
# 2  Mehmet  0.968224 -0.000417       1.127900
# 3   Tugce  0.060668 -1.168144       0.500326

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati
# Kadir   0.548051  1.295176      -0.761422
# Atlas   1.763184  0.209048       0.522082
# Mehmet  0.968224 -0.000417       1.127900
# Tugce   0.060668 -1.168144       0.500326

# %%
yeniIndexListesi = ["Kad","Atl","Meh","Tug"]

# %%
yeniDataFrame["Yeni Index"] = yeniIndexListesi

# %%
yeniDataFrame
# Out:
#             Maas       Yas  Calisma Saati Yeni Index
# Kadir   0.548051  1.295176      -0.761422        Kad
# Atlas   1.763184  0.209048       0.522082        Atl
# Mehmet  0.968224 -0.000417       1.127900        Meh
# Tugce   0.060668 -1.168144       0.500326        Tug

# %%
yeniDataFrame.set_index("Yeni Index")
# Out:
#                 Maas       Yas  Calisma Saati
# Yeni Index
# Kad         0.548051  1.295176      -0.761422
# Atl         1.763184  0.209048       0.522082
# Meh         0.968224 -0.000417       1.127900
# Tug         0.060668 -1.168144       0.500326

# %%
yeniDataFrame.set_index("Yeni Index", inplace = True)

# %%
yeniDataFrame
# Out:
#                 Maas       Yas  Calisma Saati
# Yeni Index
# Kad         0.548051  1.295176      -0.761422
# Atl         1.763184  0.209048       0.522082
# Meh         0.968224 -0.000417       1.127900
# Tug         0.060668 -1.168144       0.500326

# %%
yeniDataFrame.loc["Kad"]
# Out:
# Maas             0.548051
# Yas              1.295176
# Calisma Saati   -0.761422
# Name: Kad, dtype: float64

# %%
ilkIndexler = ["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
icIndexler = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
 birlesmisIndex = list(zip(ilkIndexler,icIndexler))

# %%
birlesmisIndex
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
birlesmisIndex = pd.MultiIndex.from_tuples(birlesmisIndex)

# %%
type(birlesmisIndex)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
birlesmisIndex
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
benimCizgiFilmListem = [[40,"A"],[10,"B"],[30,"C"],[9,"D"],[10,"E"],[11,"F"]]

# %%
cizgiFilmNumpyDizisi = np.array(benimCizgiFilmListem)

# %%
cizgiFilmDataFrame = pd.DataFrame(cizgiFilmNumpyDizisi, index = birlesmisIndex, columns = ["Yas","Meslek"])

# %%
cizgiFilmDataFrame
# Out:
#                    Yas Meslek
# Simpson    Homer    40      A
#            Bart     10      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    10      E
#            Kyle     11      F

# %%
cizgiFilmDataFrame.loc["Simpson"]
# Out:
#       Yas Meslek
# Homer  40      A
# Bart   10      B
# Marge  30      C

# %%
cizgiFilmDataFrame.loc["South Park"]
# Out:
#         Yas Meslek
# Cartman   9      D
# Kenny    10      E
# Kyle     11      F

# %%
cizgiFilmDataFrame.loc["South Park"].loc["Kenny"]
# Out:
# Yas       10
# Meslek     E
# Name: Kenny, dtype: object

# %%
cizgiFilmDataFrame.index.names = ["Film Adi", "Isim"]

# %%
cizgiFilmDataFrame
# Out:
#                    Yas Meslek
# Film Adi   Isim
# Simpson    Homer    40      A
#            Bart     10      B
#            Marge    30      C
# South Park Cartman   9      D
#            Kenny    10      E
#            Kyle     11      F
