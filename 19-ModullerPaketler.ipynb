# %%
import numpy as np
import matplotlib.pyplot as matplot

# %%
maasListesi = numpy.random.normal(4000,500,1000)
numpy.mean(maasListesi)
# Out:
# np.float64(3987.1436446771245)

# %%
matplot.hist(maasListesi,50)
matplot.show()

# %%
// Numpy verilerin oluşturulmasında mat
