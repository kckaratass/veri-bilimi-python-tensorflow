# %%
def toplama(num1,num2):
    return num1 + num2

# %%
x = int(input("İlk numarayı giriniz: "))
y = int(input("İkinci numarayı giriniz: "))
toplama(x,y)
# Out:
# İlk numarayı giriniz:  10
# İkinci numarayı giriniz:  20
# 30

# %% [markdown]
# ## try & except & else & finally

# %%
while True:
    try:
        benimInt = int(input("Numaranızı giriniz: "))
    except:
        print("lütfen gerçek bir sayı giriniz!!!")
        continue
    else:
        print("Teşekkürler")
        break
    finally:
        print("finally çağırıldı.")
# Out:
# Numaranızı giriniz:  kadir
# lütfen gerçek bir sayı giriniz!!!
# finally çağırıldı.
# Numaranızı giriniz:  5
# Teşekkürler
# finally çağırıldı.
