# %%
import numpy as np
import pandas as pd

# %%
sozluk1 = {"Isim" : ["Ahmet", "Mehmet", "Zeynep", "Kadir"], 
           "Spor" : ["Koşu", "Yüzme", "Koşu", "Basketbol"],
           "Kalori" : [100,200,300,400]
          }

# %%
dataFrame1 = pd.DataFrame(sozluk1,index = [0,1,2,3])

# %%
dataFrame1
# Out:
#      Isim       Spor  Kalori
# 0   Ahmet       Koşu     100
# 1  Mehmet      Yüzme     200
# 2  Zeynep       Koşu     300
# 3   Kadir  Basketbol     400

# %%
sozluk2 = {"Isim" : ["Osman", "Levent", "Aslı", "Fatma"], 
           "Spor" : ["Koşu", "Yüzme", "Koşu", "Basketbol"],
           "Kalori" : [200,100,50,300]
          }

# %%
dataFrame2 = pd.DataFrame(sozluk2,index = [4,5,6,7])

# %%
sozluk3 = {"Isim" : ["Ayse", "Mahmut", "Duygu", "Nur"], 
           "Spor" : ["Koşu", "Yüzme", "Badminton", "Tenis"],
           "Kalori" : [300,400,500,250]
          }

# %%
dataFrame3 = pd.DataFrame(sozluk3,index = [8,9,10,11])

# %%
dataFrame2
# Out:
#      Isim       Spor  Kalori
# 4   Osman       Koşu     200
# 5  Levent      Yüzme     100
# 6    Aslı       Koşu      50
# 7   Fatma  Basketbol     300

# %%
dataFrame3
# Out:
#       Isim       Spor  Kalori
# 8     Ayse       Koşu     300
# 9   Mahmut      Yüzme     400
# 10   Duygu  Badminton     500
# 11     Nur      Tenis     250

# %% [markdown]
# # concatenation

# %%
pd.concat([dataFrame1,dataFrame2,dataFrame3], axis = 1)
# Out:
#       Isim       Spor  Kalori    Isim       Spor  Kalori    Isim       Spor  \
# 0    Ahmet       Koşu   100.0     NaN        NaN     NaN     NaN        NaN
# 1   Mehmet      Yüzme   200.0     NaN        NaN     NaN     NaN        NaN
# 2   Zeynep       Koşu   300.0     NaN        NaN     NaN     NaN        NaN
# 3    Kadir  Basketbol   400.0     NaN        NaN     NaN     NaN        NaN
# 4      NaN        NaN     NaN   Osman       Koşu   200.0     NaN        NaN
# 5      NaN        NaN     NaN  Levent      Yüzme   100.0     NaN        NaN
# 6      NaN        NaN     NaN    Aslı       Koşu    50.0     NaN        NaN
# 7      NaN        NaN     NaN   Fatma  Basketbol   300.0     NaN        NaN
# 8      NaN        NaN     NaN     NaN        NaN     NaN    Ayse       Koşu
# 9      NaN        NaN     NaN     NaN        NaN     NaN  Mahmut      Yüzme
# 10     NaN        NaN     NaN     NaN        NaN     NaN   Duygu  Badminton
# ...

# %%
pd.concat([dataFrame1,dataFrame2,dataFrame3], axis = 0)
# Out:
#       Isim       Spor  Kalori
# 0    Ahmet       Koşu     100
# 1   Mehmet      Yüzme     200
# 2   Zeynep       Koşu     300
# 3    Kadir  Basketbol     400
# 4    Osman       Koşu     200
# 5   Levent      Yüzme     100
# 6     Aslı       Koşu      50
# 7    Fatma  Basketbol     300
# 8     Ayse       Koşu     300
# 9   Mahmut      Yüzme     400
# 10   Duygu  Badminton     500
# 11     Nur      Tenis     250

# %% [markdown]
# ## merge

# %%
mergeSozluk1 = {"Isim" : ["Ahmet", "Mehmet", "Zeynep", "Kadir"],
                "Spor" : ["Koşu", "Yüzme", "Koşu", "Basketbol"]
               }

# %%
mergeDataFrame1 = pd.DataFrame(mergeSozluk1)

# %%
mergeDataFrame1
# Out:
#      Isim       Spor
# 0   Ahmet       Koşu
# 1  Mehmet      Yüzme
# 2  Zeynep       Koşu
# 3   Kadir  Basketbol

# %%
mergeSozluk2 = {"Isim" : ["Ahmet", "Mehmet", "Zeynep", "Kadir"],
                "Kalori" : [100, 200, 150, 250]
               }

# %%
mergeDataFrame2 = pd.DataFrame(mergeSozluk2)

# %%
mergeDataFrame2
# Out:
#      Isim  Kalori
# 0   Ahmet     100
# 1  Mehmet     200
# 2  Zeynep     150
# 3   Kadir     250

# %%
pd.merge(mergeDataFrame1,mergeDataFrame2,on = "Isim")
# Out:
#      Isim       Spor  Kalori
# 0   Ahmet       Koşu     100
# 1  Mehmet      Yüzme     200
# 2  Zeynep       Koşu     150
# 3   Kadir  Basketbol     250

# %%
maasSozluk = {"Isim" : ["Kadir","Zeynep","Mehmet","Ahmet"],
              "Departman" : ["Yazılım","Satış","Pazarlama","Yazılım"],
              "Maas" : [200,300,400,500]
             }

# %%
maasDataFrame = pd.DataFrame(maasSozluk)

# %%
maasDataFrame
# Out:
#      Isim  Departman  Maas
# 0   Kadir    Yazılım   200
# 1  Zeynep      Satış   300
# 2  Mehmet  Pazarlama   400
# 3   Ahmet    Yazılım   500

# %%
maasDataFrame["Departman"].unique()
# Out:
# array(['Yazılım', 'Satış', 'Pazarlama'], dtype=object)

# %%
maasDataFrame["Departman"].nunique()
# Out:
# 3

# %%
maasDataFrame["Departman"].value_counts()
# Out:
# Departman
# Yazılım      2
# Satış        1
# Pazarlama    1
# Name: count, dtype: int64

# %%
def bruttenNete(maas):
    return maas * 0.66

# %%
maasDataFrame["Maas"].apply(bruttenNete)
# Out:
# 0    132.0
# 1    198.0
# 2    264.0
# 3    330.0
# Name: Maas, dtype: float64

# %%
maasDataFrame.isnull()
# Out:
#     Isim  Departman   Maas
# 0  False      False  False
# 1  False      False  False
# 2  False      False  False
# 3  False      False  False

# %%
yeniBirVeri = {"Karakter Sinifi" : ["South Park","South Park","Simpson","Simpson","Simpson"],
               "Karakter Ismi" : ["Cartman","Kenny","Homer","Bart","Bart"],
               "Karakter Yas" : [9,10,50,20,10]
              }

# %%
karakterDataFrame = pd.DataFrame(yeniBirVeri)

# %%
karakterDataFrame
# Out:
#   Karakter Sinifi Karakter Ismi  Karakter Yas
# 0      South Park       Cartman             9
# 1      South Park         Kenny            10
# 2         Simpson         Homer            50
# 3         Simpson          Bart            20
# 4         Simpson          Bart            10

# %%
karakterDataFrame.pivot_table(values = "Karakter Yas", index = ["Karakter Sinifi", "Karakter Ismi"],aggfunc = np.sum)
# Out:
# C:\Users\kadir\AppData\Local\Temp\ipykernel_10564\1569349147.py:1: FutureWarning: The provided callable <function sum at 0x00000206B7791260> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   karakterDataFrame.pivot_table(values = "Karakter Yas", index = ["Karakter Sinifi", "Karakter Ismi"],aggfunc = np.sum)
#                                Karakter Yas
# Karakter Sinifi Karakter Ismi
# Simpson         Bart                     30
#                 Homer                    50
# South Park      Cartman                   9
#                 Kenny                    10
